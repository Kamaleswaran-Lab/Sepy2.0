# %%
import pandas as pd

# Input file path
# encounter_path = "/hpc/home/yy450/link_kamaleswaranlab/mimic_iv/mimic_flat_files/ENCOUNTER.csv"
encounter_path = "/hpc/home/yy450/link_kamaleswaranlab/mimic_iv/builtdata/csv_exports/icu_icustays.csv"

# Output file path
output_path = "filter_test_csn.csv"

# Read ENCOUNTER.csv
df = pd.read_csv(encounter_path)

# Randomly sample 16 csn values (if fewer than 16 exist, take all)
sampled = df["hadm_id"].dropna().drop_duplicates().sample(n=16, random_state=42)
# sampled = df["hadm_id"].dropna().drop_duplicates()

# Save to CSV
sampled.to_csv(output_path, index=False)

print(f"Randomly sampled {len(sampled)} csn values and saved to {output_path}")
# Out:
# Randomly sampled 16 csn values and saved to filter_test_csn.csv
