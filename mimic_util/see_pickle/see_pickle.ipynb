# %%
import numpy, pandas; print(numpy.__version__, pandas.__version__)
# Out:
# 2.2.6 2.2.2

# %%
import pickle
import pandas as pd


file_path = "/hpc/group/kamaleswaranlab/mimic_iv/sepy_output/mimic-supertables/Supertables/20000094.pkl"
data = pickle.load(open(file_path, "rb"))

for key, value in data.items():
    print(f"{key}: {type(value)}")
# Out:
# age: <class 'pandas.core.series.Series'>
# gender: <class 'pandas.core.series.Series'>
# race: <class 'pandas.core.series.Series'>
# cci9: <class 'pandas.core.series.Series'>
# cci10: <class 'pandas.core.series.Series'>
# anion_gap: <class 'pandas.core.series.Series'>
# base_excess: <class 'pandas.core.series.Series'>
# bicarb_(hco3): <class 'pandas.core.series.Series'>
# blood_urea_nitrogen_(bun): <class 'pandas.core.series.Series'>
# calcium: <class 'pandas.core.series.Series'>
# calcium_ionized: <class 'pandas.core.series.Series'>
# chloride: <class 'pandas.core.series.Series'>
# creatinine: <class 'pandas.core.series.Series'>
# gfr: <class 'pandas.core.series.Series'>
# glucose: <class 'pandas.core.series.Series'>
# magnesium: <class 'pandas.core.series.Series'>
# osmolarity: <class 'pandas.core.series.Series'>
# phosphorus: <class 'pandas.core.series.Series'>
# potassium: <class 'pandas.core.series.Series'>
# sodium: <class 'pandas.core.series.Series'>
# haptoglobin: <class 'pandas.core.series.Series'>
# hematocrit: <class 'pandas.core.series.Series'>
# hemoglobin: <class 'pandas.core.series.Series'>
# met_hgb: <class 'pandas.core.series.Series'>
# platelets: <class 'pandas.core.series.Series'>
# white_blood_cell_count: <class 'pandas.core.series.Series'>
# carboxy_hgb: <class 'pandas.core.series.Series'>
# alanine_aminotransferase_(alt): <class 'pandas.core.series.Series'>
# albumin: <class 'pandas.core.series.Series'>
# alkaline_phosphatase: <class 'pandas.core.series.Series'>
# ammonia: <class 'pandas.core.series.Series'>
# aspartate_aminotransferase_(ast): <class 'pandas.core.series.Series'>
# bilirubin_direct: <class 'pandas.core.series.Series'>
# bilirubin_total: <class 'pandas.core.series.Series'>
# fibrinogen: <class 'pandas.core.series.Series'>
# inr: <class 'pandas.core.series.Series'>
# lactate_dehydrogenase: <class 'pandas.core.series.Series'>
# lactic_acid: <class 'pandas.core.series.Series'>
# partial_prothrombin_time_(ptt): <class 'pandas.core.series.Series'>
# prealbumin: <class 'pandas.core.series.Series'>
# protein: <class 'pandas.core.series.Series'>
# prothrombin_time_(pt): <class 'pandas.core.series.Series'>
# thrombin_time: <class 'pandas.core.series.Series'>
# transferrin: <class 'pandas.core.series.Series'>
# amylase: <class 'pandas.core.series.Series'>
# lipase: <class 'pandas.core.series.Series'>
# b-type_natriuretic_peptide_(bnp): <class 'pandas.core.series.Series'>
# troponin: <class 'pandas.core.series.Series'>
# fio2: <class 'pandas.core.series.Series'>
# partial_pressure_of_carbon_dioxide_(paco2): <class 'pandas.core.series.Series'>
# partial_pressure_of_oxygen_(pao2): <class 'pandas.core.series.Series'>
# ph: <class 'pandas.core.series.Series'>
# saturation_of_oxygen_(sao2): <class 'pandas.core.series.Series'>
# d_dimer: <class 'pandas.core.series.Series'>
# hemoglobin_a1c: <class 'pandas.core.series.Series'>
# parathyroid_level: <class 'pandas.core.series.Series'>
# thyroid_stimulating_hormone_(tsh): <class 'pandas.core.series.Series'>
# lymphocyte: <class 'pandas.core.series.Series'>
# neutrophils: <class 'pandas.core.series.Series'>
# crp_high_sens: <class 'pandas.core.series.Series'>
# procalcitonin: <class 'pandas.core.series.Series'>
# erythrocyte_sedimentation_rate_(esr): <class 'pandas.core.series.Series'>
# c_diff: <class 'pandas.core.series.Series'>
# covid: <class 'pandas.core.series.Series'>
# mtp: <class 'pandas.core.series.Series'>
# temperature: <class 'pandas.core.series.Series'>
# daily_weight_kg: <class 'pandas.core.series.Series'>
# height_cm: <class 'pandas.core.series.Series'>
# sbp_line: <class 'pandas.core.series.Series'>
# dbp_line: <class 'pandas.core.series.Series'>
# map_line: <class 'pandas.core.series.Series'>
# sbp_cuff: <class 'pandas.core.series.Series'>
# dbp_cuff: <class 'pandas.core.series.Series'>
# map_cuff: <class 'pandas.core.series.Series'>
# pulse: <class 'pandas.core.series.Series'>
# unassisted_resp_rate: <class 'pandas.core.series.Series'>
# spo2: <class 'pandas.core.series.Series'>
# end_tidal_co2: <class 'pandas.core.series.Series'>
# o2_flow_rate: <class 'pandas.core.series.Series'>
# cvp: <class 'pandas.core.series.Series'>
# temproute: <class 'pandas.core.series.Series'>
# o2_delivery_device_1: <class 'pandas.core.series.Series'>
# o2_delivery_device_2: <class 'pandas.core.series.Series'>
# o2_delivery_device_3: <class 'pandas.core.series.Series'>
# o2_delivery_device_4: <class 'pandas.core.series.Series'>
# in_or: <class 'pandas.core.series.Series'>
# proc_start: <class 'pandas.core.series.Series'>
# gcs_total_score: <class 'pandas.core.series.Series'>
# gcs_verbal_score: <class 'pandas.core.series.Series'>
# gcs_eye_score: <class 'pandas.core.series.Series'>
# gcs_motor_score: <class 'pandas.core.series.Series'>
# vent_status: <class 'pandas.core.series.Series'>
# vent_fio2: <class 'pandas.core.series.Series'>
# peep: <class 'pandas.core.series.Series'>
# vent_category: <class 'pandas.core.series.Series'>
# tidal_volume_observed: <class 'pandas.core.series.Series'>
# tidal_volume_spontaneous: <class 'pandas.core.series.Series'>
# vent_tidal_rate_set: <class 'pandas.core.series.Series'>
# vent_rate_set: <class 'pandas.core.series.Series'>
# icu: <class 'pandas.core.series.Series'>
# imc: <class 'pandas.core.series.Series'>
# ed: <class 'pandas.core.series.Series'>
# procedure: <class 'pandas.core.series.Series'>
# bed_unit: <class 'pandas.core.series.Series'>
# bed_type: <class 'pandas.core.series.Series'>
# icu_type: <class 'pandas.core.series.Series'>
# on_dialysis: <class 'pandas.core.series.Series'>
# history_of_dialysis: <class 'pandas.core.series.Series'>
# radiology_notes: <class 'pandas.core.series.Series'>
# clinical_notes: <class 'pandas.core.series.Series'>
# norepinephrine: <class 'pandas.core.series.Series'>
# epinephrine: <class 'pandas.core.series.Series'>
# dobutamine: <class 'pandas.core.series.Series'>
# dopamine: <class 'pandas.core.series.Series'>
# phenylephrine: <class 'pandas.core.series.Series'>
# vasopressin: <class 'pandas.core.series.Series'>
# norepinephrine_dose_unit: <class 'pandas.core.series.Series'>
# epinephrine_dose_unit: <class 'pandas.core.series.Series'>
# dobutamine_dose_unit: <class 'pandas.core.series.Series'>
# dopamine_dose_unit: <class 'pandas.core.series.Series'>
# phenylephrine_dose_unit: <class 'pandas.core.series.Series'>
# vasopressin_dose_unit: <class 'pandas.core.series.Series'>
# icd_procedure_desc: <class 'pandas.core.series.Series'>
# icd9_procedure_code: <class 'pandas.core.series.Series'>
# icd10_procedure_code: <class 'pandas.core.series.Series'>
# procedure_cpt_desc: <class 'pandas.core.series.Series'>
# procedure_cpt_code: <class 'pandas.core.series.Series'>
# best_map: <class 'pandas.core.series.Series'>
# pulse_pressure: <class 'pandas.core.series.Series'>
# n_to_l: <class 'pandas.core.series.Series'>
# s2f_vent_fio2: <class 'pandas.core.series.Series'>
# p2f_vent_fio2: <class 'pandas.core.series.Series'>
# norepinephrine_dose_weight: <class 'pandas.core.series.Series'>
# epinephrine_dose_weight: <class 'pandas.core.series.Series'>
# dobutamine_dose_weight: <class 'pandas.core.series.Series'>
# dopamine_dose_weight: <class 'pandas.core.series.Series'>
# phenylephrine_dose_weight: <class 'pandas.core.series.Series'>
# vasopressin_dose_weight: <class 'pandas.core.series.Series'>
# anion_gap: <class 'pandas.core.series.Series'>
# on_pressors: <class 'pandas.core.series.Series'>
# on_dobutamine: <class 'pandas.core.series.Series'>
# SIRS_resp: <class 'pandas.core.series.Series'>
# SIRS_cardio: <class 'pandas.core.series.Series'>
# SIRS_temp: <class 'pandas.core.series.Series'>
# SIRS_wbc: <class 'pandas.core.series.Series'>
# sirs_total: <class 'pandas.core.series.Series'>
# sirs_delta_24h: <class 'pandas.core.series.Series'>
# SOFA_coag: <class 'pandas.core.series.Series'>
# SOFA_renal: <class 'pandas.core.series.Series'>
# SOFA_hep: <class 'pandas.core.series.Series'>
# SOFA_neuro: <class 'pandas.core.series.Series'>
# SOFA_cardio: <class 'pandas.core.series.Series'>
# SOFA_cardio_mod: <class 'pandas.core.series.Series'>
# SOFA_resp: <class 'pandas.core.series.Series'>
# SOFA_resp_sa: <class 'pandas.core.series.Series'>
# sofa_total: <class 'pandas.core.series.Series'>
# sofa_delta_24h: <class 'pandas.core.series.Series'>
# sofa_total_mod: <class 'pandas.core.series.Series'>
# sofa_delta_24h_mod: <class 'pandas.core.series.Series'>
# meld_score: <class 'pandas.core.series.Series'>
# aki_score: <class 'pandas.core.series.Series'>
# infection: <class 'pandas.core.series.Series'>
# sepsis: <class 'pandas.core.series.Series'>
# elapsed_icu: <class 'pandas.core.series.Series'>
# elapsed_hosp: <class 'pandas.core.series.Series'>

# %%
key_to_check = "sofa_scores"   # which key you want to inspect

import pandas as pd 
pd.set_option('display.max_columns', None)

# super_table = data["super_table"] 
df = data[key_to_check]
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /hpc/dctrl/yy450/miniconda3/envs/sepy2/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'sofa_scores'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 7
#       4 pd.set_option('display.max_columns', None)
#       6 # super_table = data["super_table"]
# ----> 7 df = data[key_to_check]
#       8 df.head()
#
# File /hpc/dctrl/yy450/miniconda3/envs/sepy2/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /hpc/dctrl/yy450/miniconda3/envs/sepy2/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'sofa_scores'

# %%
key_to_check = "cultures_staging"   # which key you want to inspect
value = data[key_to_check]

print(f"==== {key_to_check} ({type(value)}) ====")

if isinstance(value, pd.DataFrame):
    print("DataFrame Size:", value.shape)
    print("Column Name:", value.columns.tolist())
    print(value.head())        
elif isinstance(value, dict):
    print("Key Number:", len(value), '\n')
    for i, (k, v) in enumerate(value.items()):
        print(f"{k}: {v}")
else:
    print(value)
# Out:
# ==== cultures_staging (<class 'pandas.core.frame.DataFrame'>) ====
# DataFrame Size: (3, 13)
# Column Name: ['pat_id', 'proc_code', 'proc_desc', 'component_id', 'component', 'loinc_code', 'specimen_collect_time', 'order_time', 'order_id', 'result_id', 'lab_result_time', 'result_status', 'lab_result']
#                                                                                                pat_id  \
# csn
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...  4c9cd243cfcd24335554a730170bb3a709cb22bed7f1d5...
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...  4c9cd243cfcd24335554a730170bb3a709cb22bed7f1d5...
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...  4c9cd243cfcd24335554a730170bb3a709cb22bed7f1d5...
#
#                                                    proc_code  \
# csn
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...   2225717
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...   2225744
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...   2225757
#
#                                                                       proc_desc  \
# csn
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...  Fecal Ova and Parasite Exam
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...      Fecal Culture Bacterial
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...     Fecal WBC/Leukocyte Test
#
#                                                     component_id component  \
# csn
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...       1891837     Feces
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...       1891837     Feces
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...       1891837     Feces
#
#                                                    loinc_code  \
# csn
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...    82213-0
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...    82213-0
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...    82213-0
#
#                                                    specimen_collect_time  \
# csn
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...   1990-04-26 08:17:20
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...   1990-04-26 08:17:20
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...   1990-04-26 08:17:20
#
#                                                             order_time  \
# csn
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0... 1990-04-26 04:47:43
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0... 1990-04-26 04:47:36
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0... 1990-04-26 04:47:39
#
#                                                     order_id       result_id  \
# csn
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...        35  22022002003254
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...        35  22022002003254
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...        35  22022002003254
#
#                                                    lab_result_time  \
# csn
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...             NaT
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...             NaT
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...             NaT
#
#                                                    result_status    lab_result
# csn
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...      Canceled  Not Recorded
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...      Canceled  Not Recorded
# 0a0a66abb51ffdc52e68bf535e94eec9f3badc14b525ee0...      Canceled  Not Recorded

# %%
import pandas as pd 
pd.set_option('display.max_columns', None)

super_table = data["super_table"] 
super_table.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /hpc/dctrl/yy450/miniconda3/envs/sepy2/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'super_table'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 4
#       1 import pandas as pd
#       2 pd.set_option('display.max_columns', None)
# ----> 4 super_table = data["super_table"]
#       5 super_table.head()
#
# File /hpc/dctrl/yy450/miniconda3/envs/sepy2/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /hpc/dctrl/yy450/miniconda3/envs/sepy2/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'super_table'

# %%
import pickle
import pandas as pd

# 1. Set file path
file_path = "/hpc/group/kamaleswaranlab/mimic_iv/sepy_output/mimic-supertables/Supertables/20000094.pkl"
output_file = "mimic_pickle_contents_summary.txt"

# 2. Read pickle
data = pickle.load(open(file_path, "rb"))

# 3. Open txt file and write contents
with open(output_file, "w", encoding="utf-8") as f:
    f.write(f"Contents of pickle file: {file_path}\n")
    for key, value in data.items():
        f.write(f"\n==== {key} ({type(value)}) ====\n")

        if isinstance(value, pd.DataFrame):
            f.write(f"DataFrame Size: {value.shape}\n")
            f.write(f"Column Names: {value.columns.tolist()}\n")
            f.write("Head (first 5 rows):\n")
            f.write(value.head().to_string() + "\n")

        elif isinstance(value, pd.Series):
            f.write(f"Series Length: {len(value)}\n")
            f.write("Head (first 5 rows):\n")
            f.write(value.head().to_string() + "\n")

        elif isinstance(value, dict):
            f.write(f"Number of Keys: {len(value)}\n")
            for i, (k, v) in enumerate(value.items()):
                f.write(f"{k}: {v}\n")
                if i >= 9:  # Only write the first 10 key-value pairs
                    f.write("... (truncated)\n")
                    break

        elif isinstance(value, (list, tuple)):
            f.write(f"Length: {len(value)}\n")
            f.write(f"First 10 items: {value[:10]}\n")

        else:
            f.write(str(value) + "\n")

print(f"✅ Output complete, contents written to {output_file}")
# Out:
# ✅ Output complete, contents written to mimic_pickle_contents_summary.txt

# %%
# 假设你已经加载好了 pickle 文件为 data
vaso_df = data.get("vasopressor_meds_staging")

if isinstance(vaso_df, pd.DataFrame):
    output_csv_path = "vasopressor_meds_staging.csv"
    vaso_df.to_csv(output_csv_path)
    print(f"✅ vasopressor_meds_staging saved to: {output_csv_path}")
else:
    print("❌ 'vasopressor_meds_staging' not found or not a DataFrame.")
# Out:
# ✅ vasopressor_meds_staging saved to: vasopressor_meds_staging.csv
