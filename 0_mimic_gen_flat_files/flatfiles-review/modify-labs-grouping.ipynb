# %%
import pandas as pd

path = "/hpc/home/yy450/link_dctrl_yy450/Sepy2.0/mimic_groupings/mimic_mapping_labs_new.csv"   
df = pd.read_csv(path)

# %%
target_ids = [50836, 51020, 51026, 51047, 51072, 51780, 51930, 51964, 51999]
df.loc[df['component_id'].isin(target_ids), 'import'] = 'No'

# %%
df.to_csv(path, index=False)

print("修改完成并保存：", path)
# Out:
# 修改完成并保存： /hpc/home/yy450/link_dctrl_yy450/Sepy2.0/mimic_groupings/mimic_mapping_labs_new.csv
