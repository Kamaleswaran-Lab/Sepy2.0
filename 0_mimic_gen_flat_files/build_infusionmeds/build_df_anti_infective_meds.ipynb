# %%
import pandas as pd

path = "/hpc/home/yy450/link_kamaleswaranlab/mimic_iv/builtdata/csv_concepts_exports/antibiotic.csv"
abx = pd.read_csv(path, dtype={"subject_id": str, "hadm_id": str, "stay_id": str}, encoding="latin1")

# %%
abx_df = abx.rename(columns={
    "hadm_id": "csn",
    "subject_id": "pat_id",
    "starttime": "med_start",
    "stoptime": "med_stop",
    "route": "med_order_route"
})

df_anti_infective_meds = abx_df[[
    "csn", "pat_id", "stay_id",
    "antibiotic", "med_start", "med_stop", "med_order_route"
]]

print(df_anti_infective_meds.head())
# Out:
#         csn    pat_id   stay_id             antibiotic            med_start  \
# 0  25124427  10783672  30442587              Cefoxitin  2133-09-12 20:00:00
# 1  25057958  10783672  34202534              Cefoxitin  2133-10-12 16:00:00
# 2  25057958  10783672  34202534              Cefoxitin  2133-10-12 14:00:00
# 3  22000149  13637586       NaN  *NF* Cefoxitin Sodium  2156-10-14 17:00:00
# 4  24303597  11249454       NaN       *NF* Ceftaroline  2164-11-26 18:00:00
#
#               med_stop med_order_route
# 0  2133-09-19 14:00:00              IV
# 1  2133-10-17 19:00:00              IV
# 2  2133-10-15 09:00:00              IV
# 3  2156-10-15 21:00:00              IV
# 4  2164-11-28 11:00:00              IJ

# %%
out_path = "/hpc/home/yy450/link_kamaleswaranlab/mimic_iv/mimic_flat_files/INFUSIONMEDS/df_anti_infective_meds.csv"
df_anti_infective_meds.to_csv(out_path, index=False)
print(f"✅ Saved anti-infective meds to {out_path}")
# Out:
# ✅ Saved anti-infective meds to /hpc/home/yy450/link_kamaleswaranlab/mimic_iv/mimic_flat_files/INFUSIONMEDS/df_anti_infective_meds.csv
