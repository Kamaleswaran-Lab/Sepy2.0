# %%
import pandas as pd

concept_path = "/hpc/home/yy450/link_kamaleswaranlab/mimic_iv/builtdata/csv_concepts_exports"
icustay_detail_path = "/hpc/home/yy450/link_kamaleswaranlab/mimic_iv/builtdata/csv_exports/icu_icustays.csv"

abx = pd.read_csv(f"{concept_path}/antibiotic.csv", dtype={"subject_id": str, "hadm_id": str, "stay_id": str}, encoding="latin1")

abx_df = abx.rename(columns={
    "antibiotic": "drug",
    "starttime": "med_order_time",
    "stoptime": "med_stop"
})

abx_df = abx_df[["subject_id", "hadm_id", "stay_id", "drug", "route", "med_order_time", "med_stop"]]

abx_df["csn"] = abx_df["hadm_id"]
abx_df["pat_id"] = abx_df["subject_id"]

df_anti_infective_meds = abx_df[[
    "csn", "pat_id", "stay_id",
    "drug", "route", "med_order_time", "med_stop"
]]

print(df_anti_infective_meds.head())

out_path = "/hpc/home/yy450/link_kamaleswaranlab/mimic_iv/mimic_flat_files/INFUSIONMEDS/df_anti_infective_meds.csv"
df_anti_infective_meds.to_csv(out_path, index=False)
print(f"✅ Saved anti-infective meds to {out_path}")
# Out:
#         csn    pat_id   stay_id                   drug route  \
# 0  25124427  10783672  30442587              Cefoxitin    IV
# 1  25057958  10783672  34202534              Cefoxitin    IV
# 2  25057958  10783672  34202534              Cefoxitin    IV
# 3  22000149  13637586       NaN  *NF* Cefoxitin Sodium    IV
# 4  24303597  11249454       NaN       *NF* Ceftaroline    IJ
#
#         med_order_time             med_stop
# 0  2133-09-12 20:00:00  2133-09-19 14:00:00
# 1  2133-10-12 16:00:00  2133-10-17 19:00:00
# 2  2133-10-12 14:00:00  2133-10-15 09:00:00
# 3  2156-10-14 17:00:00  2156-10-15 21:00:00
# 4  2164-11-26 18:00:00  2164-11-28 11:00:00
# ✅ Saved anti-infective meds to /hpc/home/yy450/link_kamaleswaranlab/mimic_iv/mimic_flat_files/INFUSIONMEDS/df_anti_infective_meds.csv
